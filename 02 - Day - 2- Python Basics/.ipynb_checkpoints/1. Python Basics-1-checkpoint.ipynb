# %% [markdown]
# ## Hello World
#
# Presentation
# ![image.png](attachment:image.png)

# %%
# !python --version
# Out:
# Python 3.7.6

# %% [markdown]
# Ways to run python
# 1. Immediate mode - cmd or terminal prompt using direct console(Command 'python' Enter)
# 2. Script mode - Create a file with .py extension - 'python file.py' Enter
# 3. Integrated Developement Environment (IDE) - spyder, pycharm, jupyter notebook

# %%
# !pwd
# Out:
# /Users/ln2/Documents/Inceptz-Batch13-Analytics_and_Python/02 - Day - 2-3-4- Python Basics

# %%
# !ls
# Out:
# 1. Python Basics-1.ipynb Hello.txt                test.py

# %%
# This is a print statement in python 3 (example for single line comment in python)
print("Hello World")
# Out:
# Hello World

# %%
# !pwd
# Out:
# /Users/ln2/Documents/Inceptz-Batch13-Analytics_and_Python/02 - Day - 2-3-4- Python Basics

# %%
# Out:
# /Users/ln2/Documents/Inceptz-Batch13-Analytics_and_Python/02 - Day - 2-3-4- Python Basics

# %%
''' 
Example for multi line commenting
What ever I write 
inside this will be 
taken as a comment
'''

# %% [markdown]
# ## Keywords, Identifiers and Variables in Python
#
# #### Keyword - it a special word that has a specific purpose

# %%
False
false

# %%
import keyword 
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# #### Identifiers - User defined names to any variable, function, class or module inside the notebook
# ###### Variables to understand identifiers - memory holders or entities whose value will change during the program execution

# %% [markdown]
# Identifier Rules :
# 1. cannot be keywords
# 2. cannot start with numbers
# 3. No space inbetween
# 4. No special character like !,@,#,$,%
# 5. It should be with range a-z and A-Z
# 6. It is case sensitive

# %%
break = 10
# Out:
#   File "<ipython-input-20-9f64e1454aa4>", line 1
#     break = 10
#           ^
# SyntaxError: invalid syntax

# %%
2laxmi = 20
# Out:
#   File "<ipython-input-21-7be6a5f87ab4>", line 1
#     2laxmi = 20
#          ^
# SyntaxError: invalid syntax

# %%
a b = 20
# Out:
#   File "<ipython-input-22-73a45dbaf58c>", line 1
#     a b = 20
#       ^
# SyntaxError: invalid syntax

# %%
@a = 20
# Out:
#   File "<ipython-input-24-ed37feed5ec1>", line 1
#     @a = 20
#        ^
# SyntaxError: invalid syntax

# %%
a = 20
b = 20

# %%
a = 27
A = 50
print("The value of a is:", a)
# Out:
# The value of a is: 27

# %%
#Assignment 
a = 5
A = 4

# %%
A
# Out:
# 4

# %%
a = b = c = 1

# %%
a,b,c = 1,2,"Azeez"

# %%
print(c)
# Out:
# Azeez

# %%
import keyword 
keyword.iskeyword("a")
# Out:
# False

# %%
import keyword 
keyword.iskeyword("try")
# Out:
# True

# %% [markdown]
# ### Data Types

# %%
a = 10
type(a)
# Out:
# int

# %%
b = 10.0
type(b)
# Out:
# float

# %%
c = True
type(c)
# Out:
# bool

# %%
d = "False"
a = 10
print(type(d))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %%
c = 1+6j
print(type(c))
# Out:
# <class 'complex'>

# %%
#List
""" 
1. Allows Heterogenous
2. Index start from 0
3. Mutable using index
4. []
"""
sample_list = [12,43,"fd",1+3j]

# %%
sample_list[3]
# Out:
# (1+3j)

# %%
sam = [12,32,45,65,35]

# %%
sam[0] = 45

# %%
sam
# Out:
# [45, 32, 45, 65, 35]

# %%
#different types of functions available 
# type list_name. + tab (can be replaced with anyother objects also)

# %%
help(sample_list.clear)
sample_list.clear?
#sample_list.clear() and pressshift+tab

# %% [markdown]
# ## List operations

# %%
#sort
sam.sort(reverse = True)
print(sam)
# Out:
# [65, 45, 45, 35, 32]

# %%
#count
sam.count(45)
# Out:
# 2

# %%
sam.extend([65,67])
print(sam)
# Out:
# [65, 45, 45, 35, 32, 65, 67, 65, 67, 65, 67, 65, 67, 65, 67]

# %%
sam2.append(2)

# %%
sam2
# Out:
# [1, 2, 40, 4, 5, 6, 2]

# %%
sam2.insert(2,10)

# %%
sam2 = [1, 2, 10, 40,5,40, 4, 5, 6, 2]

# %%
sam2.pop()
# Out:
# 2

# %%
sam2
# Out:
# [1, 2, 10, 40, 4, 5, 6]

# %%
sam2.remove(40)

# %%
sam2[3]
# Out:
# 5

# %% [markdown]
# ### List Slicing

# %%
sam2[1:4]
# Out:
# [2, 10, 40]

# %%
sam2[1:4] = 1,2,20,50

# %%
sam2
# Out:
# [1, 1, 2, 20, 50, 40, 4, 5, 6, 2]

# %%
sam2[4:]
# Out:
# [50, 40, 4, 5, 6, 2]

# %%
sam2[:4]
# Out:
# [1, 1, 2, 20]

# %%
sam2[:-1]
# Out:
# [1, 1, 2, 20, 50, 40, 4, 5, 6]

# %%
type(sam2)
# Out:
# list

# %%
#Tuple
"""
1. Allows Heterogenous
2. Retrive using index
3. Cannot change the data once declared - immutable
4. ()
"""
sample_tuple = (1,43,56,3.5,"hi",1+2j)
sample_tuple
# Out:
# (1, 43, 56, 3.5, 'hi', (1+2j))

# %%
tuple_a = ()
print(tuple_a)
# Out:
# ()

# %%
tuple_a = (1,2,3,4,2)
print(tuple_a)
# Out:
# (1, 2, 3, 4, 2)

# %%
#the variable name. + tab
tuple_a.count(2)
# Out:
# 2

# %%
tuple_a[2] = 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-0db1698b2f25> in <module>
# ----> 1 tuple_a[2] = 7
#
# TypeError: 'tuple' object does not support item assignment

# %%
sample_tuple
# Out:
# (1, 43, 56, 3.5, 'hi', (1+2j))

# %%
type(sample_tuple)
# Out:
# tuple

# %%
sample_tuple[2]
# Out:
# 56

# %%
sample_tuple[2] = 23
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-0dfca66a38a4> in <module>
# ----> 1 sample_tuple[2] = 23
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_a.index(2)
# Out:
# 1

# %%
del sample_tuple

# %%
sample_tuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-158-d6b6a49e561d> in <module>
# ----> 1 sample_tuple
#
# NameError: name 'sample_tuple' is not defined

# %%
## Difference between list and tuple - list is declared [] and tuple using ()
## Lists are mutable through index tuples are immutable

# %%
#Set
"""
1. Add heterogenous
2. Does not allow duplicates
3. Cannot access using index
4. immutable
5. sometimes can be ordered
"""

sample_set = {1,43,23,45,67,22,21,32,0,25,3,66,66,0,23,'a','abc'}

# %%
sample_set
# Out:
# {0, 1, 21, 22, 23, 25, 3, 32, 43, 45, 66, 67, 'a', 'abc'}

# %%
sample_set = {1,43,23,45,67,22,21,32,0,25,25,3,66,66,0,0,23,'a','a','abc'}

# %%
sample_set
# Out:
# {0, 1, 21, 22, 23, 25, 3, 32, 43, 45, 66, 67, 'a', 'abc'}

# %%
#TypeError: 'set' object does not support indexing - as a datatype doesnot support indexing
sample_set[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-166-e9af49f3aca4> in <module>
# ----> 1 sample_set[2]
#
# TypeError: 'set' object does not support indexing

# %%
sample_set[2]= 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-167-d2ef814e0ed5> in <module>
# ----> 1 sample_set[2]= 3
#
# TypeError: 'set' object does not support item assignment

# %%
sample_set
# Out:
# {0, 1, 21, 22, 23, 25, 3, 32, 43, 45, 66, 67, 'a', 'abc'}

# %%
#dictionary
"""
1. dictionary key value pair datastructue
2. key is unique and value can be duplicated
3. Can retrieve the value using key
4. can change the value using key
5. key is immutable

"""

sample_dict = {"a":"alpha",1:"first",2:"second",3:"third",1:"fourth",5:"fourth",6:"sixth"}

# %%
sample_dict[1]
# Out:
# 'fourth'

# %%
sample_dict[6]
# Out:
# 'sixth'

# %%
sample_dict
# Out:
# {'a': 'alpha', 1: 'fourth', 2: 'second', 3: 'third', 5: 'fourth', 6: 'sixth'}

# %%
sample_dict[2] = "Tenth"

# %%
sample_dict
# Out:
# {'a': 'alpha', 1: 'fourth', 2: 'Tenth', 3: 'third', 5: 'fourth', 6: 'sixth'}

# %%
sample_dict['a'] #I hope this clears the doubt somebody asked in the chat
# Out:
# 'alpha'

# %%
sample_dict["changed"] = sample_dict.pop("a")

# %%
sample_dict
# Out:
# {1: 'fourth',
#  2: 'Tenth',
#  3: 'third',
#  5: 'fourth',
#  6: 'sixth',
#  'changed': 'alpha'}

# %%
#String
"""
1. String can be retrieved using index
2. String is immutable

"""

a = "hi how are you?"
b = " hal"

# %%
type(a)
# Out:
# str

# %%
a[0]
# Out:
# 'h'

# %%
a[2]
# Out:
# ' '

# %%
a[2] = 'j'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-8d6d290b3117> in <module>
# ----> 1 a[2] = 'j'
#
# TypeError: 'str' object does not support item assignment

# %%
a+b
# Out:
# 'hi how are you? hal'

# %% [markdown]
# ## Type Conversion

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
a = float(a)
print(type(a))
# Out:
# <class 'float'>

# %%
s = 'Laxmi'
print("type of S", type(s))
c = tuple(s)
print("After converting a string to tuple:",c)
#print(c)
#c = tuple(c)
# Out:
# type of S <class 'str'>
# After converting a string to tuple: ('L', 'a', 'x', 'm', 'i')

# %%
lst_sample = ["l",'a','x','x','a']
lst_sample
set_sample = set(lst_sample)
print("The converted set is:" ,set_sample)
# Out:
# The converted set is: {'x', 'a', 'l'}

# %%
#you can change any 
a = 345
a = str(a)
a
# Out:
# '345'

# %%
type(a)
# Out:
# str

# %%
a = "Hello"
a = int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-068aa23699b3> in <module>
#       1 a = "Hello"
# ----> 2 a = int(a)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
a = set(a)
print("The converted set is:" ,a)
# Out:
# The converted set is: {'e', 'H', 'o', 'l'}

# %%
type(int(a[0]))

# %%
lst1 = [[1,2],[3,5],["a",["gr","ewd"]]]

# %%
lst1
# Out:
# [[1, 2], [3, 5], ['a', ['gr', 'ewd']]]

# %%
lst1[2][1][0]
# Out:
# 'gr'

# %%
dict(lst1)
# Out:
# {1: 2, 3: 5, 'a': ['gr', 'ewd']}

# %%
a = "Laxmi"
b = a 
b = "Hari"
print(b)
print(a)
# Out:
# Hari
# Laxmi

# %%
lst1 = [1,2,3,4,5]
lst2 = lst1 
lst2 = [2,3,4,5,6]
print(lst2)
print(lst1)
# Out:
# [2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5]

# %%
lst1 = [1,2,3,4,5]
lst2 = lst1 
lst2[2] = 20
print(lst2)
print(lst1)
# Out:
# [1, 2, 20, 4, 5]
# [1, 2, 20, 4, 5]
