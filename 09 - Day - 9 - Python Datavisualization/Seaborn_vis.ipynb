# %% [markdown]
# ## Seaborn
# built on the top of matplotlib. it provides high-level for drawing attractive and informative statistical information

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns #--> aliases

# %%
fifa_file = pd.read_csv("data-for-datavis/fifa.csv",index_col = 'Date',parse_dates = True)

# %%
fifa_file.head(3)
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0

# %% [markdown]
# ## Lineplot

# %%
sns.lineplot(data = fifa_file)

# %%
##initialize height and width of the figure
plt.figure(figsize = (16,6))

sns.lineplot(data = fifa_file)

# %% [markdown]
# ## Steps
# #### Step1: Load the data
# #### Step2: Examine the data
# #### Step3: Plot the data

# %%
spotify_data = pd.read_csv("data-for-datavis/spotify.csv",index_col = 'Date',parse_dates = True)

# %%
spotify_data.isna().sum()
# Out:
# Date                         0
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
sns.lineplot(data = spotify_data)

# %%
plt.figure(figsize = (16,6))
#add a title
plt.title("Popular songs streams bet 2017 and 2018")
sns.lineplot(data = spotify_data['Shape of You'],label = 'SOY')
sns.lineplot(data = spotify_data['Despacito'],label = 'Despacito')
plt.xlabel('Dates from 2017 - 18')
# Out:
# Text(0.5,0,'Dates from 2017 - 18')

# %%
plt.figure(figsize = (16,6))
#add a title
plt.title("Popular songs streams bet 2017 and 2018")
sns.lineplot(data = spotify_data['Shape of You'],label = 'SOY')
sns.lineplot(data = spotify_data['Despacito'],label = 'Despacito')
plt.xlabel('Dates from 2017 - 18')



plt.figure(figsize = (16,6))
#add a title
plt.title("Popular songs streams bet 2017 and 2018")
sns.lineplot(data = spotify_data['Shape of You'],label = 'SOY')
sns.lineplot(data = spotify_data['Despacito'],label = 'Despacito')
plt.xlabel('Dates from 2017 - 18')
# Out:
# Text(0.5,0,'Dates from 2017 - 18')

# %% [markdown]
# ## Bar plot

# %%
fight_delay = pd.read_csv("data-for-datavis/flight_delays.csv",index_col = 'Month')

# %%
fight_delay.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival delay for Spirit Airlines Flights, by month")

#defining bar plot here
sns.barplot(x = fight_delay.index,  y = fight_delay['UA'])

#Adding labels
plt.ylabel("Arrival delay Avg(in min)")
# Out:
# Text(0,0.5,'Arrival delay Avg(in min)')

# %%
## Try doing for Nk

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival delay for Spirit Airlines Flights, by month")

#defining bar plot here
sns.heatmap(data = fight_delay)

#Adding labels
plt.xlabel("Airline names")
# Out:
# Text(0.5,33,'Airline names')

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival delay for Spirit Airlines Flights, by month")


corr = fight_delay.corr()
#defining bar plot here
ax = sns.heatmap(corr,vmin = -1, vmax = 1,center = 0,annot = True)

# %%
insurance_data = pd.read_csv("data-for-datavis/insurance.csv")

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [raw]
# x = BMI
# Y = charges

# %%
sns.scatterplot(x = insurance_data['bmi'],y = insurance_data['charges'])

# %%
sns.regplot(x = insurance_data['bmi'],y = insurance_data['charges'])
# Out:
# C:\Users\AADHI\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'],hue = insurance_data['smoker'])

# %%
sns.lmplot(x = 'bmi',y = 'charges',hue = 'smoker',data = insurance_data)
# Out:
# C:\Users\AADHI\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.swarmplot(x = insurance_data['smoker'],
             y = insurance_data['charges'])

# %%
g = sns.pairplot(insurance_data)
g.set(xticklabels = [])

# %% [markdown]
# ## Distribution plots

# %%
iris_data = pd.read_csv("data-for-datavis/iris.csv",index_col = 'Id')

# %%
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
iris_data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.distplot(a = iris_data['Petal Length (cm)'],kde = False)
# Out:
# C:\Users\AADHI\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(data = iris_data['Petal Length (cm)'],shade = True)
# Out:
# C:\Users\AADHI\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x = iris_data['Petal Length (cm)'], y = iris_data['Sepal Width (cm)'],kind = "kde")
# Out:
# C:\Users\AADHI\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## What have you learnt so far?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Since it's not always easy to decide how to best tell the story behind your data, we've broken the chart types into three broad categories to help with this.
#
# - Trends - A trend is as a pattern of change.
#     - sns.lineplot - Line graphs are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
# - Relationship - There are many different chart types that you can use to understand relationships between variables in your data.
#     - sns.barplot - Bar plots are useful for comparing quantities corresponding to different groups.
#     - sns.heatmap - Heatmaps can be used to find color-coded patterns in tables of numbers.
#     - sns.scatterplot - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#     - sns.regplot - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
#     - sns.lmplot - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#     - sns.swarmplot - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
# - Distribution - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#     - sns.distplot - Histograms show the distribution of a single numerical variable.
#     - sns.kdeplot - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#     - sns.jointplot - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# ## Changing styles

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
sns.set_style('dark')
sns.lineplot(data = spotify_data)

# %%
sns.set_style('whitegrid')
sns.lineplot(data = spotify_data)

# %%
sns.set_style('ticks')
sns.lineplot(data = spotify_data)

# %%
sns.set_style('darkgrid')
sns.lineplot(data = spotify_data)

# %%
iris = sns.load_dataset("iris")
ax = sns.boxplot(data = iris,orient = 'h')

# %%
iris = sns.load_dataset("iris")
ax = sns.boxplot(data = iris)

# %%
iris = sns.load_dataset("iris")
ax = sns.boxplot(data = iris ,palette = 'Set2',color = '.25')
